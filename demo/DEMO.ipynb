# %%
import sys
sys.path.append('../')

import palette_diagram as pt
import pandas as pd

df = pd.read_csv('./dataset/example.csv', index_col=0)

# %%
pt.palette_diagram(df, norm=True)
# Out:
# ...
# n_neighbors was replaced with len(df)-1.

# %%
pt.palette_diagram(df, palette_type='linear', norm=True, cmap_name='Set1_r')
# Out:
# ...
# n_neighbors was replaced with len(df)-1.

# %%
# df_ex = pd.DataFrame(
#     np.random.poisson(1,600).reshape(100, 6),
#     columns=['category_A', 'category_B', 'category_C', 'category_D', 'category_E', 'category_F'])

# df_ex.to_csv('./dataset/example.csv')
